# %%
# using code from Sebastian Raschka's 'Build a Large Lanugage Model From Scratch'
# I may have modified the files as I'm learning.
# https://github.com/rasbt/LLMs-from-scratch/blob/main/ch02/01_main-chapter-code/dataloader.ipynb
from importlib.metadata import version

print("torch version:", version('torch'))
print('tiktoken version:', version('tiktoken'))
